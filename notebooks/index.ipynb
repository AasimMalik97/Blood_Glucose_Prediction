# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/train.csv')
# Out:
# C:\Users\malik\AppData\Local\Temp\ipykernel_28372\4229903785.py:1: DtypeWarning: Columns (435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/raw/train.csv')

# %%
df.shape
# Out:
# (177024, 508)

# %%
df.isna().sum()
# Out:
# id                    0
# p_num                 0
# time                  0
# bg-5:55           27254
# bg-5:50           18491
#                   ...
# activity-0:15    174293
# activity-0:10    174287
# activity-0:05    174271
# activity-0:00    174287
# bg+1:00               0
# Length: 508, dtype: int64

# %%
threshold = 0.5 * len(df)

# Drop columns with more than 70% missing values
df = df.dropna(axis=1, thresh=threshold)

# %%
df.shape
# Out:
# (177024, 292)

# %%
df.head()
# Out:
#       id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN
# 1  p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN
# 2  p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN
# 3  p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN
# 4  p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN
#
#    bg-5:30  bg-5:25  ...  cals-0:40  cals-0:35  cals-0:30  cals-0:25  \
# 0      9.7      NaN  ...        NaN        NaN        NaN        NaN
# 1      9.2      NaN  ...        NaN        NaN        NaN        NaN
# 2      8.7      NaN  ...        NaN        NaN        NaN        NaN
# 3      8.4      NaN  ...        NaN        NaN        NaN        NaN
# 4      8.1      NaN  ...        NaN        NaN        NaN        NaN
#
#    cals-0:20  cals-0:15  cals-0:10  cals-0:05  cals-0:00  bg+1:00
# 0        NaN        NaN        NaN        NaN        NaN     13.4
# 1        NaN        NaN        NaN        NaN        NaN     12.8
# 2        NaN        NaN        NaN        NaN        NaN     15.5
# 3        NaN        NaN        NaN        NaN        NaN     14.8
# 4        NaN        NaN        NaN        NaN        NaN     12.7
#
# [5 rows x 292 columns]

# %%
df['p_num'].value_counts()
# Out:
# p_num
# p03    26028
# p02    25872
# p10    25454
# p12    25299
# p04    24686
# p11    24555
# p01     8459
# p06     8383
# p05     8288
# Name: count, dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 10))



sns.heatmap(df.select_dtypes(include='number').corr())

plt.show()
